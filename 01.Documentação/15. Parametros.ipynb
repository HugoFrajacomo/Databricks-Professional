# %% [markdown]
# ## Parametros

# %% [markdown]
# ### Configurando parâmetros dentro do notebook

# %%
#Definindo um novo parâmetro
dbutils.widgets.text("newParam", "newParamValue")

#Forma de ler o parâmentro
newParam = dbutils.widgets.get("newParam")
print(newParam)

# %% [markdown]
# ### Configurando parâmtros pelo job

# %% [markdown]
# ![](https://img-c.udemycdn.com/redactor/raw/practice_test_question_explanation/2023-05-09_17-41-15-25709f2ec4c43f9da80d012a01117246.png)
