# %% [markdown]
# ## Permissões do Cluster
# ---
#
# - Allow cluster creation Controle total a criação de cluster
# - Cluster-level Permissions:
#   - No Permissions
#   - Can Attach to
#   - Can Restart
#   - Can Manage
#
#   ![](https://img-c.udemycdn.com/redactor/raw/practice_test_question_explanation/2024-03-24_13-24-02-0f963da2f8d373268d3b09d847899b90.png)
#
#   Link ref: https://docs.databricks.com/aws/pt/compute/clusters-manage#cluster-level-permissions
